# %% [markdown]
# <p style="font-family: Arial; font-size:2.75em;color:blue; font-style:bold"><br>
# Projet 6 :<br><br>
# Catégorisez automatiquement des questions<br><br>
# </p><br>
#
# * **Data Source / Data Source :**
#     - Data :
#         - Outils d'extraction de data : https://data.stackexchange.com/stackoverflow
#         - Script : https://github.com/EricJacquesPro/TextCategorization/blob/master/SQL/ExtractionDonnees.sql
#     - Source Python : https://github.com/EricJacquesPro/TextCategorization
# * **Description / Description : ** Projet 6 de la formation Data Scientist Proposée par OpenClassroom
#     - Analyse LDA
#     - Entrainement LDA
# * **Auteur / Author : ** Eric JACQUES
# * **Date : ** 18/07/2020

# %%
import sys
import os
import numpy as np
import pandas as pd
sys.path.insert(0, './Python/')

# %%
'''
python class for the data engineering (reading, cleaning, training...)
localised in ./Python
'''
from tagText import TagText
# Out:
# C:\Users\naru_\Anaconda3\lib\site-packages\gensim\utils.py:865: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")

# %%
tagText = TagText()
print(tagText.urlDirectory)#folder for cvs file generated by SQL query (cf. I) 
print(tagText.fileName)#name of the cvs file generated by SQL query (cf. I)
data_question = tagText.read_source()
data_question.head()

tagText.nombre_post_entree = 50000
tagText.precision = 50000
# Out:
# Data/
# QuestionVsTags.csv

# %%
data_preprocessed = data_question['body'].apply(tagText.preprocessing)
print(data_preprocessed[1:9])
# Out:
# 1    accidentally committed wrong files git pushed ...
# 2    want delete branch locally remotely failed att...
# 3                       differences git pull git fetch
# 4    ive messing around json time pushing text hurt...
# 5    use yield keyword python do example im trying ...
# 6    mistakenly added files git using command git a...
# 7    reading hidden features dark corners cstl comp...
# 8    want rename remote branch described rename mas...
# Name: body, dtype: object

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#2462C0; font-style:bold"><br>
# III.2 - Data - Bag of words - TF-IDF</p>

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#2462C0; font-style:bold"><br>
# IV.2-a - Data - Tag generator - Unsupervised - LDA</p>

# %%
perfsTrain, perfsValidation = tagText.lda_find_topic_number(
                    data_preprocessed,
                    5,
                    81,
                    2
                )
# Out:
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 5, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 7, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 9, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 11, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 13, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 15, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 17, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 19, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 21, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 23, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 25, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 27, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 29, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 31, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 33, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 35, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 37, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 39, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 41, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 43, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 45, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 47, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 49, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 51, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 53, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 55, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 57, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 59, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 61, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 63, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 65, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 67, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 69, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 71, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 73, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 75, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 77, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 79, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}

# %%
print(len(perfsTrain))
print(len(perfsValidation))
# Out:
# 38
# 38

# %%
print(max(perfsTrain))
print(max(perfsValidation))
# Out:
# -11144954.8072
# -11144954.8072

# %%
import matplotlib.pyplot as plt
import numpy as np
mini=min(perfsTrain)
x = range(5,81,2)

from sklearn.preprocessing import scale
perfs_normalized = scale( perfsTrain, axis=0, with_mean=True, with_std=True, copy=True )
x_normalized = scale( x, axis=0, with_mean=True, with_std=True, copy=True )

plt.bar(x, perfsTrain)
plt.ylabel("Performance")
plt.xlabel("number of topics")
plt.title("performance by number of topics")
plt.show()

plt.bar(x, perfs_normalized)
plt.ylabel("Performance normalized")
plt.xlabel("number of topics")
plt.title("performance normalized by number of topics")
plt.show()

perfs_topic_optimized = np.add(x_normalized, perfs_normalized)
plt.bar(x, perfs_topic_optimized)
plt.ylabel("Performance normalized + number of topic normalized")
plt.xlabel("number of topics")
plt.title("performance optimized by number of topics")
plt.show()

# %%
import matplotlib.pyplot as plt
import numpy as np
mini=min(perfsValidation)
x = range(5,81,2)

from sklearn.preprocessing import scale
perfs_normalized = scale( perfsValidation, axis=0, with_mean=True, with_std=True, copy=True )
x_normalized = scale( x, axis=0, with_mean=True, with_std=True, copy=True )

plt.bar(x, perfsValidation)
plt.ylabel("Performance")
plt.xlabel("number of topics")
plt.title("performance by number of topics")
plt.show()

plt.bar(x, perfs_normalized)
plt.ylabel("Performance normalized")
plt.xlabel("number of topics")
plt.title("performance normalized by number of topics")
plt.show()

perfs_topic_optimized = np.add(x_normalized, perfs_normalized)
plt.bar(x, perfs_topic_optimized)
plt.ylabel("Performance normalized + number of topic normalized")
plt.xlabel("number of topics")
plt.title("performance optimized by number of topics")
plt.show()

# %%
    def lda_predict(
        model,
        text,
        lda,
        lda_df_topic_keywords,
        lda_tf_vectorizer,
        no_top_words
    ):
        '''
        predict tag form text in function of lda, topic ad tf vectorizer
        '''
        text = [text]
        mytext = lda_tf_vectorizer.transform(text)
        lda_topic_probability_scores = lda.transform(mytext)
        lda_topic = lda_df_topic_keywords.iloc[
            tagText.np.argmax(lda_topic_probability_scores),
            :
        ].values.tolist()
        topic_array = model.np.array(lda_topic)
        lda_feature_names = lda_tf_vectorizer.get_feature_names()
        return (
            " ".join(
                        [
                            lda_feature_names[i]
                            for i in topic_array.argsort()
                            [
                                :-no_top_words - 1:-1
                            ]
                        ]
                )
        )

# %%
lda_tagText, df_topic_keywords, tf_vectorizer = tagText.lda_prepare_tag(data_preprocessed, 32)

print(lda_predict(tagText, 'I cannot intall a git repository. I try github and gitlab', lda_tagText, df_topic_keywords, tf_vectorizer, 5))
print(tagText.lda_predict( "How to cast number as integer in java", lda_tagText, df_topic_keywords, tf_vectorizer, 5))
# Out:
# C:\Users\naru_\Anaconda3\lib\site-packages\sklearn\decomposition\online_lda.py:294: DeprecationWarning: n_topics has been renamed to n_components in version 0.19 and will be removed in 0.21
#   DeprecationWarning)
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 32, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# Log Likelihood:  -18997621.8565
# Perplexity:  8009.42791632
# {'evaluate_every': -1, 'max_doc_update_iter': 100, 'doc_topic_prior': None, 'verbose': 0, 'n_jobs': -1, 'learning_offset': 10.0, 'random_state': 100, 'n_topics': 32, 'topic_word_prior': None, 'mean_change_tol': 0.001, 'total_samples': 1000000.0, 'n_components': 10, 'batch_size': 128, 'perp_tol': 0.1, 'max_iter': 10, 'learning_method': 'online', 'learning_decay': 0.7}
# git branch repository changes remote
# int 10 number long compiler

# %%
print(lda_predict(tagText, 'I cannot intall a git repository. I try github and gitlab', lda_tagText, df_topic_keywords, tf_vectorizer, 5))
# Out:
# git branch repository changes remote

# %%
print(tagText.lda_predict( "How to cast number as integer in java", lda_tagText, df_topic_keywords, tf_vectorizer, 5))
# Out:
# int 10 number long compiler

# %%
print(tagText.lda_predict( "How to cast number as integer in java", lda_tagText, df_topic_keywords, tf_vectorizer, 10))
# Out:
# int 10 number long compiler return code performance const include

# %%
from joblib import dump, load
dump(lda_tagText, 'lda.joblib',0)
dump(df_topic_keywords, 'df_lda_topic_keywords.joblib',0)
dump(tf_vectorizer, 'tf_lda_vectorizer.joblib',0)
# Out:
# ['tf_lda_vectorizer.joblib']

# %%
def display_topics(model, feature_names, no_top_words):
    for topic_idx, topic in enumerate(model.components_):
        print("Topic :", topic_idx, ":" )
        print (" ".join([feature_names[i]
                        for i in topic.argsort()[:-no_top_words - 1:-1]]))

no_top_words = 5
print('Topics : ')
display_topics(lda_tagText, tf_vectorizer.get_feature_names(), no_top_words)
# Out:
# Topics :
# Topic : 0 :
# server request foo bar post
# Topic : 1 :
# set application html app script
# Topic : 2 :
# input jquery multiple lines event
# Topic : 3 :
# new object objects create properties
# Topic : 4 :
# numpy ex register num 255
# Topic : 5 :
# import component template match expression
# Topic : 6 :
# thanks process rails os open
# Topic : 7 :
# table select database data query
# Topic : 8 :
# file files run directory command
# Topic : 9 :
# test date item string var
# Topic : 10 :
# view button click left screen
# Topic : 11 :
# list value key values field
# Topic : 12 :
# web model url framework aspnet
# Topic : 13 :
# code java exception run error
# Topic : 14 :
# class public string return method
# Topic : 15 :
# like im way want using
# Topic : 16 :
# git branch repository changes remote
# Topic : 17 :
# error line file message following
# Topic : 18 :
# int 10 number long compiler
# Topic : 19 :
# use question used difference methods
# Topic : 20 :
# true false thing lot google
# Topic : 21 :
# project studio visual info compile
# Topic : 22 :
# service let body strings says
# Topic : 23 :
# user page tag users session
# Topic : 24 :
# void android new override xml
# Topic : 25 :
# div image css width text
# Topic : 26 :
# size memory explain language time
# Topic : 27 :
# python def link library eclipse
# Topic : 28 :
# php allows plugins webpack bundle
# Topic : 29 :
# required argument calling struct starting
# Topic : 30 :
# version install installed package npm
# Topic : 31 :
# icon scala param shape usespermission

# %%
print('Topics From working class : ')
tagText.display_topics(lda_tagText, tf_vectorizer.get_feature_names(), no_top_words)
# Out:
# Topics From working class :
# Topic : 0 :
# server request foo bar post
# Topic : 1 :
# set application html app script
# Topic : 2 :
# input jquery multiple lines event
# Topic : 3 :
# new object objects create properties
# Topic : 4 :
# numpy ex register num 255
# Topic : 5 :
# import component template match expression
# Topic : 6 :
# thanks process rails os open
# Topic : 7 :
# table select database data query
# Topic : 8 :
# file files run directory command
# Topic : 9 :
# test date item string var
# Topic : 10 :
# view button click left screen
# Topic : 11 :
# list value key values field
# Topic : 12 :
# web model url framework aspnet
# Topic : 13 :
# code java exception run error
# Topic : 14 :
# class public string return method
# Topic : 15 :
# like im way want using
# Topic : 16 :
# git branch repository changes remote
# Topic : 17 :
# error line file message following
# Topic : 18 :
# int 10 number long compiler
# Topic : 19 :
# use question used difference methods
# Topic : 20 :
# true false thing lot google
# Topic : 21 :
# project studio visual info compile
# Topic : 22 :
# service let body strings says
# Topic : 23 :
# user page tag users session
# Topic : 24 :
# void android new override xml
# Topic : 25 :
# div image css width text
# Topic : 26 :
# size memory explain language time
# Topic : 27 :
# python def link library eclipse
# Topic : 28 :
# php allows plugins webpack bundle
# Topic : 29 :
# required argument calling struct starting
# Topic : 30 :
# version install installed package npm
# Topic : 31 :
# icon scala param shape usespermission
