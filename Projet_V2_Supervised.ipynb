# %% [markdown]
# <p style="font-family: Arial; font-size:2.75em;color:blue; font-style:bold"><br>
# Projet 6 :<br><br>
# Catégorisez automatiquement des questions<br><br>
# </p><br>
#
# * **Data Source / Data Source :**
#     - Data :
#         - Outils d'extraction de data : https://data.stackexchange.com/stackoverflow
#         - Script : https://github.com/EricJacquesPro/TextCategorization/blob/master/SQL/ExtractionDonnees.sql
#     - Source Python : https://github.com/EricJacquesPro/TextCategorization
# * **Description / Description : ** Projet 6 de la formation Data Scientist Proposée par OpenClassroom
#     - Analyse Supervised
#     - Entrainement Supervised
# * **Auteur / Author : ** Eric JACQUES
# * **Date : ** 16/06/2020

# %% [markdown]
# <p style="font-family: Arial; font-size:1.75em;color:#2462C0; font-style:bold"><br>
# I - Sélection des datas entrantes</p>

# %%
import sys
import os
import numpy as np
import pandas as pd
sys.path.insert(0, './Python/')
'''
python class for the data engineering (reading, cleaning, training...)
localised in ./Python
'''
from tagText import TagText 
tagText = TagText()

tagText.nombre_post_entree = 500
tagText.precision = 500

print(tagText.urlDirectory)#folder for cvs file generated by SQL query (cf. I) 
print(tagText.fileName)#name of the cvs file generated by SQL query (cf. I)
data_question = tagText.read_source()
print(data_question.head())


data_preprocessed = data_question['body'].apply(tagText.preprocessing)

print(data_preprocessed.head())

classifier, tags = tagText.supervised_prepare_tag(data_preprocessed, data_question['SelectedTags'])
message = 'git est un outils de code source. C\'est bien'
print(message)

print(tagText.supervised_predict(message, classifier, tags))
# Out:
# C:\Users\naru_\Anaconda3\lib\site-packages\gensim\utils.py:865: UserWarning: detected Windows; aliasing chunkize to chunkize_serial
#   warnings.warn("detected Windows; aliasing chunkize to chunkize_serial")
# Data/
# QuestionVsTags.csv
#          Id                                               body  \
# 0  11227809  <p>Here is a piece of C++ code that shows some...
# 1    927358  <p>I accidentally committed the wrong files to...
# 2   2003505  <p>I want to delete a branch both locally and ...
# 3    292357  <p>What are the differences between <code>git ...
# 4    477816  <p>I've been messing around with <a href="http...
#
#                                                title  \
# 0  Why is processing a sorted array faster than p...
# 1  How do I undo the most recent local commits in...
# 2  How do I delete a Git branch locally and remot...
# 3  What is the difference between 'git pull' and ...
# 4             What is the correct JSON content type?
#
#                                                 tags  \
# 0  <java><c++><performance><optimization><branch-...
# 1  <git><version-control><git-commit><undo><pre-c...
# 2  <git><version-control><git-branch><git-push><g...
# 3        <git><version-control><git-pull><git-fetch>
# 4                 <json><http-headers><content-type>
#
#                                SelectedTags      Name
# 0        java,c++,performance,optimization,  Question
# 1           git,version-control,git-commit,  Question
# 2  git,version-control,git-branch,git-push,  Question
# 3                      git,version-control,  Question
# 4           json,http-headers,content-type,  Question
# 0    piece c code shows peculiar behavior strange r...
# 1    accidentally committed wrong files git pushed ...
# 2    want delete branch locally remotely failed att...
# 3                       differences git pull git fetch
# 4    ive messing around json time pushing text hurt...
# Name: body, dtype: object
# git est un outils de code source. C'est bien
# ['git', 'html', 'java', 'javascript', 'jquery', 'python', 'string']

# %%
print(tagText.supervised_predict(data_preprocessed[0], classifier, tags ))
# Out:
# ['.net' 'abstract-class' 'actionscript' 'aix' 'ajax' 'algorithm' 'alias'
#  'alignment' 'anchor' 'android' 'android-activity' 'android-context'
#  'android-edittext' 'android-layout' 'android-softkeyboard' 'angularjs'
#  'angularjs-service' 'apache-flex' 'append' 'arguments' 'arraylist'
#  'arrays' 'artificial-intelligence' 'asp.net' 'assembly' 'assert'
#  'assignment-operator' 'asynchronous' 'atomic' 'attr' 'attributes'
#  'authentication' 'autocomplete' 'background-color' 'bash' 'benchmarking'
#  'big-o' 'bit-manipulation' 'bitwise-operators' 'bower' 'branch'
#  'branching-and-merging' 'browser' 'browser-cache' 'build-automation'
#  'build-process' 'button' 'c' 'c#' 'c++' 'c++11' 'caching' 'casting'
#  'centering' 'certificate' 'char' 'character-encoding' 'checkbox' 'chmod'
#  'class' 'click' 'clone' 'closures' 'cocoa-touch' 'code-formatting'
#  'coldfusion' 'collections' 'command' 'command-line'
#  'command-line-arguments' 'command-line-interface' 'comments' 'compare'
#  'comparison' 'compatibility' 'compiler-optimization' 'complexity-theory'
#  'computer-science' 'concat' 'concatenation' 'conditional-statements'
#  'constructor' 'containers' 'contains' 'content-type' 'copy'
#  'copy-constructor' 'coroutine' 'cors' 'cross-browser' 'css'
#  'css-selectors' 'css-shapes' 'css-transitions' 'csv' 'curl' 'currency'
#  'cycle' 'data-binding' 'data-conversion' 'data-structures' 'database'
#  'dataframe' 'date' 'date-formatting' 'datetime' 'decimal' 'decorator'
#  'definition' 'delete-file' 'dependency-injection' 'design-patterns'
#  'dictionary' 'diff' 'dimensions' 'directory' 'docker' 'dockerfile' 'dom'
#  'dom-events' 'double' 'drop-down-menu' 'duplicates' 'dynamic'
#  'dynamic-memory-allocation' 'each' 'echo' 'eclipse' 'ecmascript-6'
#  'editor' 'emacs' 'email' 'email-validation' 'enumeration' 'enums'
#  'environment-variables' 'equality' 'error-handling' 'escaping'
#  'event-handling' 'events' 'excel' 'exception' 'exception-handling'
#  'executable-jar' 'export' 'express' 'extend' 'facebook' 'file' 'file-io'
#  'file-upload' 'filenames' 'filesystems' 'flash' 'floating-accuracy'
#  'floating-point' 'focus' 'for-loop' 'foreach' 'formatting' 'forms' 'fs'
#  'function' 'functional-programming' 'garbage-collection' 'gcc' 'generator'
#  'geometry' 'getline' 'getter' 'git' 'git-branch' 'git-commit' 'git-merge'
#  'git-push' 'git-rebase' 'git-submodules' 'github' 'gitignore'
#  'global-variables' 'google-chrome' 'google-chrome-devtools' 'graph' 'grep'
#  'group-concat' 'gruntjs' 'guid' 'gulp' 'hashmap' 'hashtable' 'heap'
#  'highlight' 'homebrew' 'html' 'html-parsing' 'html-select' 'html-table'
#  'http' 'http-get' 'http-headers' 'http-status-code-403'
#  'http-status-codes' 'httprequest' 'httpurlconnection' 'hyperlink'
#  'idisposable' 'iis' 'iis-7' 'image' 'image-processing' 'import' 'include'
#  'indentation' 'indexing' 'inheritance' 'initialization' 'inner-classes'
#  'inner-join' 'inputstream' 'installation' 'int' 'integer' 'interface'
#  'inversion-of-control' 'io' 'ios' 'iostream' 'iteration' 'iterator' 'java'
#  'javabeans' 'javascript' 'javascript-objects' 'join' 'jquery'
#  'jquery-selectors' 'json' 'jsonp' 'jsp' 'junit' 'junit4' 'jython'
#  'keyboard-shortcuts' 'ksh' 'lambda' 'language-agnostic' 'language-design'
#  'language-lawyer' 'layout' 'left-join' 'linked-list' 'linq' 'linux'
#  'linux-kernel' 'list' 'listview' 'local-storage' 'lodash' 'logging'
#  'logic' 'lookup' 'loops' 'macos' 'macros' 'main' 'makefile' 'malloc'
#  'margin' 'markdown' 'matching' 'math' 'maven-2' 'memory' 'memory-leaks'
#  'memory-management' 'merge' 'methods' 'mkdir' 'mobile'
#  'model-view-controller' 'module' 'move-semantics' 'ms-word'
#  'multidimensional-array' 'multiline' 'multithreading' 'mvp' 'mysql'
#  'namespaces' 'nested-loops' 'networking' 'new-operator' 'newline'
#  'node.js' 'notepad++' 'npm' 'null' 'nullpointerexception'
#  'nullreferenceexception' 'numbers' 'object' 'objective-c' 'oop' 'opacity'
#  'opencv' 'operating-system' 'operators' 'optimization' 'orm' 'outer-join'
#  'overloading' 'overwrite' 'package' 'package.json' 'padding' 'pandas'
#  'parameter-passing' 'parameters' 'parsing' 'pass-by-reference' 'passwords'
#  'path' 'pdf' 'pdf-generation' 'performance' 'permissions' 'php' 'pip'
#  'pixel' 'placeholder' 'plugins' 'pointers' 'polygon' 'port' 'posix' 'post'
#  'postgresql' 'postgresql-9.1' 'powershell' 'printf' 'printing' 'private'
#  'process' 'profile' 'profiling' 'properties' 'protected' 'psql' 'public'
#  'pull-request' 'push' 'put' 'python' 'python-2.7' 'python-3.x'
#  'python-decorators' 'python-module' 'query-string' 'r' 'radio-button'
#  'random' 'range' 'rebase' 'recursion' 'redirect' 'reference' 'reflection'
#  'refresh' 'regex' 'regex-group' 'regex-negation' 'reload' 'remote-server'
#  'rename' 'replace' 'repository' 'rest' 'return' 'rounding' 'rows' 'ruby'
#  'runnable' 'same-origin-policy' 'sass' 'scope' 'scp' 'screen' 'scripting'
#  'scroll' 'search' 'security' 'sed' 'select' 'serialization' 'setter' 'sh'
#  'shell' 'singleton' 'sleep' 'slice' 'smart-pointers' 'soap' 'sorting'
#  'split' 'spring-mvc' 'sql' 'sql-injection' 'sql-order-by' 'sql-server'
#  'sql-server-2000' 'sql-server-2005' 'sql-server-2008' 'sql-server-2012'
#  'sql-server-2016' 'sqldatatypes' 'sqlite' 'ssh' 'stack' 'static'
#  'static-methods' 'std' 'stream' 'string' 'string-concatenation'
#  'string-matching' 'subprocess' 'substring' 'super' 'switch-statement'
#  'symbols' 'symlink' 'syntax' 'syntax-error' 'tail-recursion' 'tdd'
#  'templates' 'terminal' 'terminology' 'ternary-operator' 'text-parsing'
#  'textview' 'tfs' 'time' 'time-complexity' 'timestamp' 'timezone' 'trim'
#  'tsql' 'type-conversion' 'types' 'typescript' 'uikeyboard' 'uikit'
#  'uilabel' 'uiscrollview' 'uitextfield' 'undefined' 'underscore.js'
#  'uniqueidentifier' 'unit-testing' 'unix' 'unix-timestamp' 'uppercase'
#  'uri' 'url' 'url-rewriting' 'urlencode' 'user-interface' 'uuid' 'vagrant'
#  'validation' 'var' 'variable-assignment' 'variables' 'variadic-functions'
#  'vb.net' 'vectorization' 'version-control' 'versioning'
#  'vertical-alignment' 'vi' 'vim' 'virtual-machine' 'virtualenv'
#  'virtualization' 'visibility' 'visual-studio' 'web-applications' 'webpack'
#  'windows' 'windows-server-2008-r2' 'wsdl' 'xml' 'xml-parsing' 'yield'
#  'youtube' 'youtube-api' 'youtube-data-api']
# ['git', 'html', 'java', 'javascript', 'jquery', 'python', 'string']
# ['git', 'html', 'java', 'javascript', 'jquery', 'python', 'string']

# %%
print (tags)

# %%
data_question['SelectedTags']

# %%
from sklearn.preprocessing import MultiLabelBinarizer
    
data_tag = data_question['SelectedTags']

y_all = [
            item[:-1].split(',')#-1 car il y a un ',' à la fin de la ligne
            for item in data_tag
        ]

#print(y_train_tag)
lb = MultiLabelBinarizer()
Y_all = lb.fit_transform(y_all)
print(y_all)

# %%
len(Y_all)
print(len(Y_all[0]))

# %%
print(lb.classes_)

# %%
for i in range(1, 499 , 1):
    print(Y_all[i])

# %%
from sklearn.model_selection import train_test_split
X = data_preprocessed#[str(item) for item in data_preprocessed]
'''y_train_tag = [
    item[:-1].split(',')#-1 car il y a un ',' à la fin de la ligne
    for item in data_tag
]'''
y = data_question['SelectedTags']
print(X.head())
print(y.head())

X_train, X_test, y_pre_train, y_pre_test = train_test_split(X, y, test_size=0.33)#, random_state=42)
print(X_train.head())
print(y_pre_train.head())

# %%
tagText.supervised_predict(data_preprocessed[0], classifier, tags )

# %%
classifier.predict_proba([text])

# %%
from sklearn.feature_extraction.text import TfidfVectorizer
from sklearn.manifold import TSNE

X = tf_idf_matrix.todense()

X = data_preprocessed

# t-SNE plot
embeddings = TSNE(n_components=5)
Y = embeddings.fit_transform(X)
plt.scatter(Y[:, 0], Y[:, 1], cmap=plt.cm.Spectral)
plt.show()
